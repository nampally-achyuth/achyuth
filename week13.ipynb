# %% [markdown]
# <a href="https://colab.research.google.com/github/nampally-achyuth/achyuth/blob/main/week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.Series([10,20,30,40,50])
py_list=data.tolist()
print("pandas series:")
print(data)
print('converted  py list')
print(py_list)
# Out:
# pandas series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# converted  py list
# [10, 20, 30, 40, 50]

# %%
# Out:
# ERROR: You must give at least one requirement to install (see "pip help install")
