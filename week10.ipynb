# %% [markdown]
# <a href="https://colab.research.google.com/github/nampally-achyuth/achyuth/blob/main/week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  print("Result:",int(input("Enter a number:"))//int(input("Enter a number:")))
except ValueError:
  print("Invalid input!,Please enter a valit input.")
except ZeroDivisionError:
  print("Cannot divide by zero")
# Out:
# Enter a number:10
# Enter a number:0
# Cannot divide by zero

# %%
try:
  numbers=[10,20,30,40,50,60]
  print("element:",numbers[index:=int(input("enter the index numberer:"))])
except IndexError:
  print("Error:index out of range!")
except ValueError:
  print("error:invalid input..try again.")
except Exception as e:
  print("Unexpected error occured",e)
# Out:
# enter the index numberer:10
# Error:index out of range!

# %%
class InvalidAgeError(Exception):
  pass
try:
  age=int(input("Enter the age:"))
  if age >= 18:
    print("Eligible")
  else:
    raise InvalidAgeError("Age must be greater than or equal to 18")
except InvalidAgeError as e:
  print("Custom Exception:",e)
except ValueError:
  print("Invalid input")
# Out:
# Enter the age:14
# Custom Exception: Age must be greater than or equal to 18

# %%
class InvalidAgeError(Exception):
  pass
try:
  age=int(input("Enter the age:"))
  if age>=18: print("Eligible")
  else: raise InvalidAgeError("Age must be greater than or equal to 18")
except (InvalidAgeError, ValueError) as e:
  print("Exception:", e)
# Out:
# Enter the age:45
# Eligible
